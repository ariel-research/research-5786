# %%
import pandas as pd

# %%
df = pd.read_csv("2019.csv")
# happiness report for year 2019. From here: https://www.kaggle.com/datasets/unsdsn/world-happiness?select=2019.csv
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df.head(30)
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 0              1               Finland  7.769           1.340           1.587
# 1              2               Denmark  7.600           1.383           1.573
# 2              3                Norway  7.554           1.488           1.582
# 3              4               Iceland  7.494           1.380           1.624
# 4              5           Netherlands  7.488           1.396           1.522
# 5              6           Switzerland  7.480           1.452           1.526
# 6              7                Sweden  7.343           1.387           1.487
# 7              8           New Zealand  7.307           1.303           1.557
# 8              9                Canada  7.278           1.365           1.505
# 9             10               Austria  7.246           1.376           1.475
# 10            11             Australia  7.228           1.372           1.548
# ...

# %%
df.tail(10)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 146           147                     Haiti  3.597           0.323
# 147           148                  Botswana  3.488           1.041
# 148           149                     Syria  3.462           0.619
# 149           150                    Malawi  3.410           0.191
# 150           151                     Yemen  3.380           0.287
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 146           0.688                    0.449                         0.026
# 147           1.145                    0.538                         0.455
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# ## Selecting columns

# %%
print(df['Country or region'])
print(df['Country or region'].tolist())
df['Country or region'].to_dict()
# Out:
# 0                       Finland
# 1                       Denmark
# 2                        Norway
# 3                       Iceland
# 4                   Netherlands
#                  ...
# 151                      Rwanda
# 152                    Tanzania
# 153                 Afghanistan
# 154    Central African Republic
# 155                 South Sudan
# Name: Country or region, Length: 156, dtype: object
# ...

# %%
df[['Country or region','Generosity']] #shows only these two columns
# Out:
#             Country or region  Generosity
# 0                     Finland       0.153
# 1                     Denmark       0.252
# 2                      Norway       0.271
# 3                     Iceland       0.354
# 4                 Netherlands       0.322
# ..                        ...         ...
# 151                    Rwanda       0.217
# 152                  Tanzania       0.276
# 153               Afghanistan       0.158
# 154  Central African Republic       0.235
# 155               South Sudan       0.202
#
# [156 rows x 2 columns]

# %%
df[['Country or region','Generosity']].head(10) #shows top 10 countries. NOTE: The data is not sorted yet.
# Out:
#   Country or region  Generosity
# 0           Finland       0.153
# 1           Denmark       0.252
# 2            Norway       0.271
# 3           Iceland       0.354
# 4       Netherlands       0.322
# 5       Switzerland       0.263
# 6            Sweden       0.267
# 7       New Zealand       0.330
# 8            Canada       0.285
# 9           Austria       0.244

# %% [markdown]
# ## Selecting rows

# %%
### iloc - select a row by serial number
print(df.iloc[2])
print(df.iloc[2].to_dict())
# Out:
# Overall rank                         3
# Country or region               Norway
# Score                            7.554
# GDP per capita                   1.488
# Social support                   1.582
# Healthy life expectancy          1.028
# Freedom to make life choices     0.603
# Generosity                       0.271
# Perceptions of corruption        0.341
# Name: 2, dtype: object
# {'Overall rank': 3, 'Country or region': 'Norway', 'Score': 7.554, 'GDP per capita': 1.488, 'Social support': 1.582, 'Healthy life expectancy': 1.028, 'Freedom to make life choices': 0.603, 'Generosity': 0.271, 'Perceptions of corruption': 0.341}

# %%
### loc - select a row by key
df_country = pd.read_csv("2019.csv", index_col = 'Country or region')
print(df_country)
# Out:
#                           Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                              1  7.769           1.340           1.587
# Denmark                              2  7.600           1.383           1.573
# Norway                               3  7.554           1.488           1.582
# Iceland                              4  7.494           1.380           1.624
# Netherlands                          5  7.488           1.396           1.522
# ...                                ...    ...             ...             ...
# Rwanda                             152  3.334           0.359           0.711
# Tanzania                           153  3.231           0.476           0.885
# Afghanistan                        154  3.203           0.350           0.517
# Central African Republic           155  3.083           0.026           0.000
# South Sudan                        156  2.853           0.306           0.575
#
# ...

# %%
df_country.loc['Israel']
# Out:
# Overall rank                    13.000
# Score                            7.139
# GDP per capita                   1.276
# Social support                   1.455
# Healthy life expectancy          1.029
# Freedom to make life choices     0.371
# Generosity                       0.261
# Perceptions of corruption        0.082
# Name: Israel, dtype: float64

# %%
df['Perceptions of corruption'] < 0.03  # very corrupt
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153     True
# 154    False
# 155    False
# Name: Perceptions of corruption, Length: 156, dtype: bool

# %%
# Find countries with low score on the corruption column (= high perception of corruption)
df[df['Perceptions of corruption'] < 0.03]
# Out:
#      Overall rank       Country or region  Score  GDP per capita  \
# 37             38                Slovakia  6.198           1.246
# 38             39       Trinidad & Tobago  6.192           1.231
# 45             46                  Kosovo  6.100           0.882
# 47             48                 Romania  6.070           1.162
# 51             52                Thailand  6.008           1.050
# 55             56                 Jamaica  5.890           0.831
# 61             62                 Hungary  5.758           1.201
# 64             65                    Peru  5.697           0.960
# 65             66                Portugal  5.693           1.221
# 70             71                 Moldova  5.529           0.685
# 74             75                 Croatia  5.432           1.155
# 77             78  Bosnia and Herzegovina  5.386           0.945
# 79             80                Malaysia  5.339           1.221
# ...

# %%
df[df['Perceptions of corruption'] < 0.03][['Country or region','Perceptions of corruption']]
# Out:
#           Country or region  Perceptions of corruption
# 37                 Slovakia                      0.014
# 38        Trinidad & Tobago                      0.016
# 45                   Kosovo                      0.006
# 47                  Romania                      0.005
# 51                 Thailand                      0.028
# 55                  Jamaica                      0.028
# 61                  Hungary                      0.020
# 64                     Peru                      0.027
# 65                 Portugal                      0.025
# 70                  Moldova                      0.000
# 74                  Croatia                      0.022
# 77   Bosnia and Herzegovina                      0.006
# 79                 Malaysia                      0.024
# 85               Kyrgyzstan                      0.023
# 86             Turkmenistan                      0.028
# 90                  Lebanon                      0.027
# ...

# %%
# Find countries that are conceived as at least as corrupt as Israel
corrupt_countries = df[df['Perceptions of corruption'] <=df_country.loc['Israel']['Perceptions of corruption']]
corrupt_countries[['Country or region','Perceptions of corruption']].head(10)
# Out:
#    Country or region  Perceptions of corruption
# 12            Israel                      0.082
# 19    Czech Republic                      0.036
# 22            Mexico                      0.073
# 25             Chile                      0.056
# 26         Guatemala                      0.078
# 29             Spain                      0.079
# 30            Panama                      0.054
# 34       El Salvador                      0.074
# 35             Italy                      0.030
# 37          Slovakia                      0.014

# %%
corrupt_countries.to_csv('At least as corrupt as Israel.csv')

# %% [markdown]
# ## Queries

# %%
df.query("`Perceptions of corruption` < 0.1 and `Generosity` > 0.3")
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 51             52          Thailand  6.008           1.050           1.409
# 91             92         Indonesia  5.192           0.931           1.203
# 120           121             Kenya  4.509           0.512           0.983
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 51                     0.828                         0.557       0.359
# 91                     0.660                         0.491       0.498
# 120                    0.581                         0.431       0.372
#
#      Perceptions of corruption
# 51                       0.028
# 91                       0.028
# 120                      0.053

# %%
df.query("`Perceptions of corruption` < 0.1 and `Generosity` > 0.3")[["Country or region","Perceptions of corruption","Generosity"]]
# Out:
#     Country or region  Perceptions of corruption  Generosity
# 51           Thailand                      0.028       0.359
# 91          Indonesia                      0.028       0.498
# 120             Kenya                      0.053       0.372

# %% [markdown]
#  ## Sorting

# %%
df.sort_values(by=['Perceptions of corruption'],ascending=False)[['Country or region', 'Perceptions of corruption']]
# Out:
#           Country or region  Perceptions of corruption
# 33                Singapore                      0.453
# 151                  Rwanda                      0.411
# 1                   Denmark                      0.410
# 0                   Finland                      0.393
# 7               New Zealand                      0.380
# ..                      ...                        ...
# 77   Bosnia and Herzegovina                      0.006
# 45                   Kosovo                      0.006
# 47                  Romania                      0.005
# 96                 Bulgaria                      0.004
# 70                  Moldova                      0.000
#
# [156 rows x 2 columns]

# %%
df.sort_values(by=['GDP per capita'],ascending=False)[['Country or region', 'GDP per capita']]
# Out:
#             Country or region  GDP per capita
# 28                      Qatar           1.684
# 13                 Luxembourg           1.609
# 33                  Singapore           1.572
# 20       United Arab Emirates           1.503
# 50                     Kuwait           1.500
# ..                        ...             ...
# 126          Congo (Kinshasa)           0.094
# 140                   Liberia           0.073
# 144                   Burundi           0.046
# 154  Central African Republic           0.026
# 111                   Somalia           0.000
#
# [156 rows x 2 columns]

# %%
df.iloc[1:6]
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
# 5                    1.052                         0.572       0.263
#
#    Perceptions of corruption
# 1                      0.410
# 2                      0.341
# ...

# %% [markdown]
# ## Applying a function to all rows

# %%
def to_lower_case(row):
    return row['Country or region'].lower()  # return only the country, and in lower-case

df_lower = df.apply(to_lower_case, axis=1)  # Apply the function row-by-row
df_lower
# Out:
# 0                       finland
# 1                       denmark
# 2                        norway
# 3                       iceland
# 4                   netherlands
#                  ...
# 151                      rwanda
# 152                    tanzania
# 153                 afghanistan
# 154    central african republic
# 155                 south sudan
# Length: 156, dtype: object

# %%
def duplicate_country(col):
    return col[1]+col[1]  # return only 2nd country, and add each column to itself

df_test = df.apply(duplicate_country, axis=0)   # Apply the function col-by-col
df_test
# Out:
# Overall rank                                 4
# Country or region               DenmarkDenmark
# Score                                     15.2
# GDP per capita                           2.766
# Social support                           3.146
# Healthy life expectancy                  1.992
# Freedom to make life choices             1.184
# Generosity                               0.504
# Perceptions of corruption                 0.82
# dtype: object

# %%
df['Country or region'] = df_lower   # update the original DataFrame
df.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           finland  7.769           1.340           1.587
# 1             2           denmark  7.600           1.383           1.573
# 2             3            norway  7.554           1.488           1.582
# 3             4           iceland  7.494           1.380           1.624
# 4             5       netherlands  7.488           1.396           1.522
# 5             6       switzerland  7.480           1.452           1.526
# 6             7            sweden  7.343           1.387           1.487
# 7             8       new zealand  7.307           1.303           1.557
# 8             9            canada  7.278           1.365           1.505
# 9            10           austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
# Adding a new column
df['Country or region Uppercase'] = df.apply(lambda row: row['Country or region'].upper(), axis=1)
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   finland  7.769           1.340
# 1               2                   denmark  7.600           1.383
# 2               3                    norway  7.554           1.488
# 3               4                   iceland  7.494           1.380
# 4               5               netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    rwanda  3.334           0.359
# 152           153                  tanzania  3.231           0.476
# 153           154               afghanistan  3.203           0.350
# 154           155  central african republic  3.083           0.026
# 155           156               south sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
# Adding a new column
df['Support-by-generosity'] = df.apply(lambda row: row['Social support']/(row['Generosity']+0.001), axis=1)
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   finland  7.769           1.340
# 1               2                   denmark  7.600           1.383
# 2               3                    norway  7.554           1.488
# 3               4                   iceland  7.494           1.380
# 4               5               netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    rwanda  3.334           0.359
# 152           153                  tanzania  3.231           0.476
# 153           154               afghanistan  3.203           0.350
# 154           155  central african republic  3.083           0.026
# 155           156               south sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
# The following code swaps the columns' contents, not their position:
temp = df['Support-by-generosity']
df['Support-by-generosity'] = df['Score']
df['Score'] = temp

# The following code also swaps their position:
df = df.rename(columns={"Support-by-generosity": "Score", "Score": "Support-by-generosity"})
df
# Out:
#      Overall rank         Country or region  Support-by-generosity  \
# 0               1                   finland              10.305195
# 1               2                   denmark               6.217391
# 2               3                    norway               5.816176
# 3               4                   iceland               4.574648
# 4               5               netherlands               4.712074
# ..            ...                       ...                    ...
# 151           152                    rwanda               3.261468
# 152           153                  tanzania               3.194946
# 153           154               afghanistan               3.251572
# 154           155  central african republic               0.000000
# 155           156               south sudan               2.832512
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0             1.340           1.587                    0.986
# ...

# %% [markdown]
# ## Plotting

# %%
df['Social support'].plot();

# %%
df['Social support'].hist();

# %%
df[['Generosity','Healthy life expectancy']].hist();

# %% [markdown]
# ## Grouping

# %%
import numpy as np
df["RoundedScore"] = np.round(df["Score"])
df.head(10)
# Out:
#    Overall rank Country or region  Support-by-generosity  GDP per capita  \
# 0             1           finland              10.305195           1.340
# 1             2           denmark               6.217391           1.383
# 2             3            norway               5.816176           1.488
# 3             4           iceland               4.574648           1.380
# 4             5       netherlands               4.712074           1.396
# 5             6       switzerland               5.780303           1.452
# 6             7            sweden               5.548507           1.387
# 7             8       new zealand               4.703927           1.303
# 8             9            canada               5.262238           1.365
# 9            10           austria               6.020408           1.376
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.587                    0.986                         0.596
# ...

# %%
df.groupby(["RoundedScore"]).count()
# Out:
#               Overall rank  Country or region  Support-by-generosity  \
# RoundedScore
# 3.0                      9                  9                      9
# 4.0                     26                 26                     26
# 5.0                     48                 48                     48
# 6.0                     49                 49                     49
# 7.0                     21                 21                     21
# 8.0                      3                  3                      3
#
#               GDP per capita  Social support  Healthy life expectancy  \
# RoundedScore
# 3.0                        9               9                        9
# 4.0                       26              26                       26
# 5.0                       48              48                       48
# 6.0                       49              49                       49
# 7.0                       21              21                       21
# ...

# %%
df.groupby(["RoundedScore"])[["Score", "Social support", "Generosity"]].mean()
# Out:
#                  Score  Social support  Generosity
# RoundedScore
# 3.0           3.271556        0.659333    0.196667
# 4.0           4.179923        0.978154    0.202038
# 5.0           4.985292        1.123104    0.175562
# 6.0           6.009041        1.373898    0.153041
# 7.0           7.082143        1.487476    0.248143
# 8.0           7.641000        1.580667    0.225333

# %%
df.groupby(["RoundedScore"])[["Score", "Social support", "Generosity"]].max()
# Out:
#               Score  Social support  Generosity
# RoundedScore
# 3.0           3.488           1.163       0.331
# 4.0           4.490           1.390       0.566
# 5.0           5.467           1.538       0.498
# 6.0           6.446           1.529       0.359
# 7.0           7.494           1.624       0.375
# 8.0           7.769           1.587       0.271
